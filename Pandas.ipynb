# %% [markdown]
# Pandas is a Python library used for working with data sets.
# It has functions for analyzing, cleaning, exploring, and manipulating data

# %% [markdown]
# ### <font color=green>**Data Exploration**</font>
#
# 1.Reading and writing csv/excel---------read_/to_
#
# 2.Getting preview of data---------------head/tail/column
#
# 3.Renaming columns----------------------rename({})
#
# 4.selecting columns/rows----------------loc/iloc
#
# 5.Handling Missing values---------------dropna/fillna()
#
# 6.Creating new columns------------------
#
# 7.Aggregate-----------------------------groupby
#
# 8.Merging/concatenating-----------------concat/join
#
# 9.Applying function to element/column---map/apply/applymap
#
# 10.Identify unique value----------------unique
#
# 11.Basic stats--------------------------describe/corr

# %%
import pandas as pd

student_dataset={'NAME':['Aishwarya','Anuradha','Afrin'],
                'ROLL NUM':[2,3,1]}
print(pd.DataFrame(student_dataset))
# Out:
#         NAME  ROLL NUM
# 0  Aishwarya         2
# 1   Anuradha         3
# 2      Afrin         1

# %% [markdown]
# Dataframe is collection of series , series is like a column in table

# %%
print(pd.Series(student_dataset))

ROLL_NUM = [2,3,1]
print(pd.Series(ROLL_NUM))
# Out:
# NAME        [Aishwarya, Anuradha, Afrin]
# ROLL NUM                       [2, 3, 1]
# dtype: object
# 0    2
# 1    3
# 2    1
# dtype: int64

# %% [markdown]
# Creating labels
# With the index argument, we can name/create your own labels.

# %%
import pandas as pd

Name = ['Aishwarya','Anuradha','Afrin']
myattendance = pd.Series(Name, index = ["x", "y", "z"])

print(myattendance)
print(myattendance["y"])
# Out:
# x    Aishwarya
# y     Anuradha
# z        Afrin
# dtype: object
# Anuradha

# %% [markdown]
# ### <font color=deeppink>1.Reading and writing files</font>

# %%
df = pd.read_csv('/home/neosoft/Desktop/Aishwarya_codes/Datasets/50_Startups.csv')

# %%
df.to_excel('excel_from_python.xlsx',sheet_name='sheet1')

# %% [markdown]
# To read excel --------read_excel

# %% [markdown]
# ### <font color=deeppink>2.To preview data</font>

# %%
print(df.head(4))
print(df.tail(4))
print(df[2:10:2])
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 6  134615.46       147198.87        127716.82  California  156122.51
# ...

# %% [markdown]
# ### <font color=deeppink>3.Renaming columns</font>

# %%
df1 = pd.read_csv('/home/neosoft/Desktop/Aishwarya_codes/Datasets/50_Startups.csv',nrows=10)
#inplace to make chnages in original dataset 
df1.rename(columns={'State':'States','Profit':'Profits'},inplace=True)#renaming

# %%
display(df1.head(3))
df1.columns
# Out:
#    R&D Spend  Administration  Marketing Spend      States    Profits
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'States', 'Profits'], dtype='object')

# %% [markdown]
# ### <font color=deeppink>4.Selection</font>

# %%
#Selecting data based on some condition -----loc
display(df.loc[(df.State == 'New York')].head(5))
display(df.loc[2:10:2])#row based
display(df.iloc[:,0:2].head(5))#in iloc firstpart deals with rows followed by columns
display(df.loc[(df.State == 'New York'),['State','Profit']].head(5))#condition and column
# Out:
#     R&D Spend  Administration  Marketing Spend     State     Profit
# 0   165349.20       136897.80        471784.10  New York  192261.83
# 3   144372.41       118671.85        383199.62  New York  182901.99
# 5   131876.90        99814.71        362861.36  New York  156991.12
# 8   120542.52       148718.95        311613.29  New York  152211.77
# 15  114523.61       122616.84        261776.23  New York  129917.04
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 6   134615.46       147198.87        127716.82  California  156122.51
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 10  101913.08       110594.11        229160.95     Florida  146121.95
#    R&D Spend  Administration
# 0  165349.20       136897.80
# 1  162597.70       151377.59
# 2  153441.51       101145.55
# ...

# %% [markdown]
# ### <font color=deeppink>5.Handling Missing values</font>

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
data_missing=pd.read_csv('/home/neosoft/Desktop/Aishwarya_codes/Datasets/travel-times.csv')
data_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            205 non-null    object
#  1   StartTime       205 non-null    object
#  2   DayOfWeek       205 non-null    object
#  3   GoingTo         205 non-null    object
#  4   Distance        205 non-null    float64
#  5   MaxSpeed        205 non-null    float64
#  6   AvgSpeed        205 non-null    float64
#  7   AvgMovingSpeed  205 non-null    float64
#  8   FuelEconomy     188 non-null    object
#  9   TotalTime       205 non-null    float64
#  10  MovingTime      205 non-null    float64
#  11  Take407All      205 non-null    object
#  12  Comments        24 non-null     object
# dtypes: float64(6), object(7)
# memory usage: 20.9+ KB

# %%
print(data_missing.isnull().sum())
# Out:
# Date                0
# StartTime           0
# DayOfWeek           0
# GoingTo             0
# Distance            0
# MaxSpeed            0
# AvgSpeed            0
# AvgMovingSpeed      0
# FuelEconomy        17
# TotalTime           0
# MovingTime          0
# Take407All          0
# Comments          181
# dtype: int64

# %%
data_missing.head(10)
# Out:
#          Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0    1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1    1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2    1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3    1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4    1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
# 5    1/3/2012     07:57    Tuesday     GSK     51.80     135.8      84.5
# 6    1/2/2012     17:31     Monday    Home     51.37     123.2      82.9
# 7    1/2/2012     07:34     Monday     GSK     49.01     128.3      77.5
# 8  12/23/2011     08:01     Friday     GSK     52.91     130.3      80.9
# 9  12/22/2011     17:19   Thursday    Home     51.17     122.3      70.6
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# 0            84.8         NaN       39.3        36.3         No      NaN
# ...

# %% [markdown]
# fillna(0),fillna(method ='pad')#previous,fillna(method ='bfill')#next

# %%
data_missing.dropna(axis=1,inplace=True)#axis=0 rows,axis=1 columns
display(data_missing.head(10))
# Out:
#          Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0    1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1    1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2    1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3    1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4    1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
# 5    1/3/2012     07:57    Tuesday     GSK     51.80     135.8      84.5
# 6    1/2/2012     17:31     Monday    Home     51.37     123.2      82.9
# 7    1/2/2012     07:34     Monday     GSK     49.01     128.3      77.5
# 8  12/23/2011     08:01     Friday     GSK     52.91     130.3      80.9
# 9  12/22/2011     17:19   Thursday    Home     51.17     122.3      70.6
#
#    AvgMovingSpeed  TotalTime  MovingTime Take407All
# 0            84.8       39.3        36.3         No
# 1            88.9       37.9        34.9         No
# ...

# %%
display(data_missing.head(3))
data_missing['FuelEconomy'].fillna(data_missing['FuelEconomy'].mode()[0],inplace=True)
display(data_missing.head(5))
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# 0            84.8         NaN       39.3        36.3         No      NaN
# 1            88.9         NaN       37.9        34.9         No      NaN
# 2            85.8         NaN       37.5        35.9         No      NaN
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# ...

# %%
print(data_missing.duplicated().sum())  #drop_duplicated
# Out:
# 0

# %% [markdown]
# ### <font color=deeppink>6.Creating new columns</font>

# %%
display(df.head(5))
df['newcolumn']=df['State']+'USA'
display(df.head(3))
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
#
#        newcolumn
# 0    New YorkUSA
# 1  CaliforniaUSA
# 2     FloridaUSA

# %% [markdown]
# ### <font color=deeppink>7.Aggregate</font>

# %%
gkk = df.groupby(['State'])
  

gkk.first()
# Out:
#             R&D Spend  Administration  Marketing Spend     Profit  \
# State
# California  162597.70       151377.59        443898.53  191792.06
# Florida     153441.51       101145.55        407934.54  191050.39
# New York    165349.20       136897.80        471784.10  192261.83
#
#                 newcolumn
# State
# California  CaliforniaUSA
# Florida        FloridaUSA
# New York      New YorkUSA

# %%
display(df.groupby(['Profit']).sum().head(10))
# Out:
#           R&D Spend  Administration  Marketing Spend
# Profit
# 14681.40       0.00       116983.80         45173.06
# 35673.41     542.05        51743.15             0.00
# 42559.73       0.00       135426.92             0.00
# 49490.75    1315.46       115816.21        297114.46
# 64926.08    1000.23       124153.04          1903.93
# 65200.33   22177.74       154806.14         28334.72
# 69758.98   15505.73       127382.30         35534.17
# 71498.49   23640.93        96189.63        148001.11
# 77798.83   27892.92        84710.77        164470.71
# 78239.91   28754.33       118546.05        172795.67

# %% [markdown]
# ### <font color=deeppink>8.Merging/concatenating</font>

# %% [markdown]
# Merge--- method updates the content of two DataFrame by merging them together, using the specified methods.

# %%
display(df.head(3))
df1.head(3)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
#
#        newcolumn
# 0    New YorkUSA
# 1  CaliforniaUSA
# 2     FloridaUSA
#    R&D Spend  Administration  Marketing Spend      States    Profits
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39

# %%
pd.concat([df,df1])#combining dataframes based on columns
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data1 = {
  "name": ["Sally", "Mary", "John"],
  "age": [50, 40, 30]
}

data2 = {
  "name": ["Sally", "Peter", "Micky"],
  "age": [77, 44, 22]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

newdf = df1.merge(df2, how='right') 

display(newdf)
display(df1.merge(df2, how='left'))
# Out:
#     name  age
# 0  Sally   77
# 1  Peter   44
# 2  Micky   22
#     name  age
# 0  Sally   50
# 1   Mary   40
# 2   John   30

# %%
newdf2=pd.concat([df1,df2])
newdf2
# Out:
#     name  age
# 0  Sally   50
# 1   Mary   40
# 2   John   30
# 0  Sally   77
# 1  Peter   44
# 2  Micky   22

# %% [markdown]
# ### <font color=deeppink>9.Applying function to element/column</font>

# %%
newdf2['age']=newdf2['age'].map(lambda x:x+10)

display(newdf2)
# Out:
#     name  age
# 0  Sally   60
# 1   Mary   50
# 2   John   40
# 0  Sally   87
# 1  Peter   54
# 2  Micky   32

# %% [markdown]
# ### <font color=deeppink>10.Identify unique value</font>

# %%
data_missing.shape
# Out:
# (205, 13)

# %%
data_missing.nunique()
# Out:
# Date              111
# StartTime         123
# DayOfWeek           5
# GoingTo             2
# Distance          124
# MaxSpeed          113
# AvgSpeed          159
# AvgMovingSpeed    147
# FuelEconomy        24
# TotalTime         122
# MovingTime        110
# Take407All          2
# Comments           22
# dtype: int64

# %%
data_missing['DayOfWeek'].unique()
# Out:
# array(['Friday', 'Wednesday', 'Tuesday', 'Monday', 'Thursday'],
#       dtype=object)

# %% [markdown]
# ### <font color=deeppink>11.Basic stats</font>

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
display(df.corr())
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %% [markdown]
# Visualization

# %%
df['Profit'].hist()
# Out:
# <AxesSubplot:>
